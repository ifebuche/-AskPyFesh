# %%
import pandas as pd

# %%
#######
#pandas.read_fwf(filepath_or_buffer: Union[str, pathlib.Path, IO[~AnyStr]], colspecs='infer', widths=None, 
#infer_nrows=100, **kwds)
#Read a table of fixed-width formatted lines into DataFrame.
#Also supports optionally iterating or breaking of the file into chunks."""
########

#df = pd.read_fwf("WhatsApp Chat with #AskPyFesh.txt", encoding="utf-8", header=None)
#reads empty lines and returns them as Nan. Not pretty.

# %%
wats = pd.read_csv("WhatsApp Chat with #AskPyFesh.txt", delimiter="\t", header=None)

# %%
wats.shape
# Out:
# (405, 1)

# %%
wats.columns = ["message"]

# %%
wats.head()
# Out:
#                                              message
# 0  10/22/19, 1:26 PM - Messages to this group are...
# 1  10/22/19, 1:26 PM - You created group "#AskPyF...
# 2   10/22/19, 1:28 PM - MaduDOMINIC: Ask Python Fesh
# 3            10/22/19, 1:28 PM - MaduDOMINIC: Odi ok
# 4      10/22/19, 1:28 PM - MaduDOMINIC: Anyi ebidogo

# %%
wats.tail()
# Out:
#                                                message
# 400                                           _-Fesh-_
# 401  10/24/19, 8:40 AM - +234 812 481 1464: Kudos @...
# 402  10/24/19, 8:44 AM - Budo: I'm getting confused...
# 403  10/24/19, 8:46 AM - Paschal Chukwuemeka Amah: ...
# 404  10/24/19, 9:06 AM - +1 (647) 679-8746 joined u...

# %%
#Convert to list for flexibility
g1 = wats.message.to_list()

# %%
msgs = []
pos = 0
for i, line in enumerate(g1):
    line = line.lower()
    try:
        num = int(line[:2]) #Start of line, see if a date which will start with a number
        if num:
            msgs.append(line)
            pos += 1
    except:
        """
        So it's not a number/date meaning its line 2 the prev line.
        Check if the line before it starts with a number/date
        """
        try: #checking
            num = int(g1[i-1][:2]) #line being tried
            if num: #if number then (stop)
                msg_now = g1[i-1]+ " " + line #current and prev lines are same convo. merge them
                msgs.append(msg_now) #put in the list
                msgs.pop(pos-1) #remove the previous line item
                #pos -= 1
                #end of show
        except: #Gets here if it's not a number, so it's a continuation still
            """
            Since it's not a number/date, means it's line 3 of the prev2 lines.
            """
            try: #check if two lines before it starts with a number
                num = int(g1[i-2][:2]) #checking
                if num: #if number then (stop)
                    msg_now = g1[i-2]+ " " + g1[i-1] + " " + line #current and prev2 lines are same convo. merge them
                    msgs.append(msg_now) #put in list
                    #delete last 2 lines
                    msgs.pop(pos-1)
                    #msgs.pop(-1)
            except: #Gets here if it's not a number, so it's a continuation still
                """
                Since it's not a number/date, means it's line 4 of the prev3 lines.
                """
                try: #check if three lines before it starts with a number
                    num = int(g1[i-3][:2]) #checking
                    if num: #if number then (stop)
                        msg_now = g1[i-3] + " " + g1[i-2]+ " " + g1[i-1] + " " + line #current and prev3 lines are same convo. merge them
                        msgs.append(msg_now) #put in list
                        #delete last 3 lines
                        msgs.pop(pos-1)
                        #msgs.pop(-1)
                        #msgs.pop(-1)
                except: #Gets here if it's not a number, so it's a continuation still
                    """
                    Since it's not a number/date, means it's line 5 of the prev4 lines.
                    """
                    try: #check if three lines before it starts with a number
                        num = int(g1[i-4][:2]) #checking
                        if num: #if number then (stop)
                            msg_now = g1[i-4] + " " + g1[i-3] + " " + g1[i-2]+ " " + g1[i-1] + " " + line #current and prev3 lines are same convo. merge them
                            msgs.append(msg_now) #put in list
                            #delete last 4 lines
                            msgs.pop(pos-1)
                            #msgs.pop(-1)
                            #msgs.pop(-1)
                            #msgs.pop(-1)
                    except: #Gets here if it's not a number, so it's a continuation still
                        """
                        Since it's not a number/date, means it's line 6 of the prev5 lines.
                        """
                        try: #check if four lines before it starts with a number
                            num = int(g1[i-5][:2]) #checking
                            if num: #if number then (stop)
                                msg_now = g1[i-5] + " " + g1[i-4] + " " + g1[i-3] + " " + g1[i-2]+ " " + g1[i-1] + " " + line #current and prev3 lines are same convo. merge them
                                msgs.append(msg_now) #put in list
                                #delete last 5 lines
                                msgs.pop(pos-1)
                        except: #Gets here if it's not a number, so it's a continuation still
                            """
                            Since it's not a number/date, means it's line 7 of the prev6 lines.
                            """
                            try: #check if five lines before it starts with a number
                                num = int(g1[i-6][:2]) #checking
                                if num: #if number then (stop)
                                    msg_now = g1[i-6] + " " + g1[i-5] + " " + g1[i-4] + " " + g1[i-3] + " " + g1[i-2]+ " " + g1[i-1] + " " + line #current and prev3 lines are same convo. merge them
                                    msgs.append(msg_now) #put in list
                                    #delete last 5 lines
                                    msgs.pop(pos-1)
                            except: #Gets here if it's not a number, so it's a continuation still
                                """
                                Since it's not a number/date, means it's line 8 of the prev7 lines.
                                """
                                try: #check if five lines before it starts with a number
                                    num = int(g1[i-7][:2]) #checking
                                    if num: #if number then (stop)
                                        msg_now = g1[i-7] + " " + g1[i-6] + " " + g1[i-5] + " " + g1[i-4] + " " + g1[i-3] + " " + g1[i-2]+ " " + g1[i-1] + " " + line #current and prev3 lines are same convo. merge them
                                        msgs.append(msg_now) #put in list
                                        #delete last 5 lines
                                        msgs.pop(pos-1)
                                except: #Gets here if it's not a number, so it's a continuation still
                                    """
                                    Since it's not a number/date, means it's line 9 of the prev8 lines.
                                    """
                                    try: #check if five lines before it starts with a number
                                        num = int(g1[i-8][:2]) #checking
                                        if num: #if number then (stop)
                                            msg_now = g1[i-8] + " " + g1[i-7] + " " + g1[i-6] + " " + g1[i-5] + " " + g1[i-4] + " " + g1[i-3] + " " + g1[i-2]+ " " + g1[i-1] + " " + line #current and prev3 lines are same convo. merge them
                                            msgs.append(msg_now) #put in list
                                            #delete last 5 lines
                                            msgs.pop(pos-1)
                                    except: #Gets here if it's not a number, so it's a continuation still
                                        """
                                        Since it's not a number/date, means it's line 10 of the prev9 lines.
                                        """
                                        try: #check if five lines before it starts with a number
                                            num = int(g1[i-9][:2]) #checking
                                            if num: #if number then (stop)
                                                msg_now = g1[i-9] + " " + g1[i-8] + " " + g1[i-7] + " " + g1[i-6] + " " + g1[i-5] + " " + g1[i-4] + " " + g1[i-3] + " " + g1[i-2]+ " " + g1[i-1] + " " + line #current and prev3 lines are same convo. merge them
                                                msgs.append(msg_now) #put in list
                                                #delete last 5 lines
                                                msgs.pop(pos-1)   
                                        except: #Gets here if it's not a number, so it's a continuation still
                                            """
                                            Since it's not a number/date, means it's line 11 of the prev10 lines.
                                            """
                                            try: #check if five lines before it starts with a number
                                                num = int(g1[i-10][:2]) #checking
                                                if num: #if number then (stop)
                                                    msg_now = g1[i-10] + " " + g1[i-9] + " " + g1[i-8] + " " + g1[i-7] + " " + g1[i-6] + " " + g1[i-5] + " " + g1[i-4] + " " + g1[i-3] + " " + g1[i-2]+ " " + g1[i-1] + " " + line #current and prev3 lines are same convo. merge them
                                                    msgs.append(msg_now) #put in list
                                                    #delete last 5 lines
                                                    msgs.pop(pos-1)
                                            except: #Gets here if it's not a number, so it's a continuation still
                                                """
                                                Since it's not a number/date, means it's line 12 of the prev11 lines.
                                                """
                                                try: #check if five lines before it starts with a number
                                                    num = int(g1[i-11][:2]) #checking
                                                    if num: #if number then (stop)
                                                        msg_now = g1[i-11] + " " + g1[i-10] + " " + g1[i-9] + " " + g1[i-8] + " " + g1[i-7] + " " + g1[i-6] + " " + g1[i-5] + " " + g1[i-4] + " " + g1[i-3] + " " + g1[i-2]+ " " + g1[i-1] + " " + line #current and prev3 lines are same convo. merge them
                                                        msgs.append(msg_now) #put in list
                                                        #delete last 5 lines
                                                        msgs.pop(pos-1)
                                                except: #Gets here if it's not a number, so it's a continuation still
                                                    """
                                                    Since it's not a number/date, means it's line 13 of the prev12 lines.
                                                    """
                                                    try: #check if five lines before it starts with a number
                                                        num = int(g1[i-12][:2]) #checking
                                                        if num: #if number then (stop)
                                                            msg_now = g1[i-12] + " " + g1[i-11] + " " + g1[i-10] + " " + g1[i-9] + " " + g1[i-8] + " " + g1[i-7] + " " + g1[i-6] + " " + g1[i-5] + " " + g1[i-4] + " " + g1[i-3] + " " + g1[i-2]+ " " + g1[i-1] + " " + line #current and prev3 lines are same convo. merge them
                                                            msgs.append(msg_now) #put in list
                                                            #delete last 5 lines
                                                            msgs.pop(pos-1)
                                                    except: #Gets here if it's not a number, so it's a continuation still
                                                        """
                                                        Since it's not a number/date, means it's line 14 of the prev13 lines.
                                                        """
                                                        try: #check if five lines before it starts with a number
                                                            num = int(g1[i-13][:2]) #checking
                                                            if num: #if number then (stop)
                                                                msg_now = g1[i-13] + " " + g1[i-12] + " " + g1[i-11] + " " + g1[i-10] + " " + g1[i-9] + " " + g1[i-8] + " " + g1[i-7] + " " + g1[i-6] + " " + g1[i-5] + " " + g1[i-4] + " " + g1[i-3] + " " + g1[i-2]+ " " + g1[i-1] + " " + line #current and prev3 lines are same convo. merge them
                                                                msgs.append(msg_now) #put in list
                                                                #delete last 5 lines
                                                                msgs.pop(pos-1)
                                                        except: #Gets here if it's not a number, so it's a continuation still
                                                            """
                                                            Since it's not a number/date, means it's line 15 of the prev14 lines.
                                                            """
                                                            try: #check if five lines before it starts with a number
                                                                num = int(g1[i-14][:2]) #checking
                                                                if num: #if number then (stop)
                                                                    msg_now = g1[i-14] + " " + g1[i-13] + " " + g1[i-12] + " " + g1[i-11] + " " + g1[i-10] + " " + g1[i-9] + " " + g1[i-8] + " " + g1[i-7] + " " + g1[i-6] + " " + g1[i-5] + " " + g1[i-4] + " " + g1[i-3] + " " + g1[i-2]+ " " + g1[i-1] + " " + line #current and prev3 lines are same convo. merge them
                                                                    msgs.append(msg_now) #put in list
                                                                    #delete last 5 lines
                                                                    msgs.pop(pos-1)    
                                                            except:
                                                                print("I'm left out man!\n{}\n\n".format(len(msgs)))

# %%
len(g1)
for i, line in enumerate(g1):
    print(i, line)
# Out:
# 0 10/22/19, 1:26 PM - Messages to this group are now secured with end-to-end encryption. Tap for more info.
# 1 10/22/19, 1:26 PM - You created group "#AskPyFesh "
# 2 10/22/19, 1:28 PM - MaduDOMINIC: Ask Python Fesh
# 3 10/22/19, 1:28 PM - MaduDOMINIC: Odi ok
# 4 10/22/19, 1:28 PM - MaduDOMINIC: Anyi ebidogo
# 5 10/22/19, 1:30 PM - You changed the group description
# 6 10/22/19, 1:30 PM - Paschal Chukwuemeka Amah: Hehe.
# 7 Na so.
# 8 10/22/19, 1:30 PM - Paschal Chukwuemeka Amah: Trying to find the next big pythonista.
# 9 So, historically na Igwe enter the group first.
# 10 10/22/19, 1:31 PM - Paschal Chukwuemeka Amah: I'll delete all this sha just before I start sharing links and having people join.
# 11 10/22/19, 1:34 PM - You changed this group's icon
# 12 10/22/19, 1:35 PM - You changed this group's icon
# 13 10/22/19, 1:46 PM - You changed the group description
# 14 10/22/19, 8:00 PM - Adafin joined using this group's invite link
# 15 10/22/19, 8:00 PM - +234 818 559 0066 joined using this group's invite link
# 16 10/22/19, 8:10 PM - +234 703 120 1331 joined using this group's invite link
# 17 10/22/19, 8:14 PM - +234 906 883 7990 joined using this group's invite link
# 18 10/22/19, 8:17 PM - +234 805 052 8131 joined using this group's invite link
# 19 10/22/19, 8:23 PM - Valentine D-GASM joined using this group's invite link
# 20 10/22/19, 8:26 PM - Ojei Toritsemoshe D-GASM joined using this group's invite link
# 21 10/22/19, 8:32 PM - Chigozie Njoku D-GASM joined using this group's invite link
# 22 10/22/19, 8:33 PM - Chigozie Njoku D-GASM: #AskFeshIntro
# 23 Name: Chigozie Njoku
# 24 City of residence: Lagos
# 25 10/22/19, 8:34 PM - +234 706 444 3217 joined using this group's invite link
# 26 10/22/19, 8:34 PM - +234 816 629 7839 joined using this group's invite link
# 27 10/22/19, 8:37 PM - +234 810 004 6353 joined using this group's invite link
# 28 10/22/19, 8:37 PM - +234 810 086 7971 joined using this group's invite link
# 29 10/22/19, 8:39 PM - +234 805 052 8131: #AskFeshIntro
# 30 Taofik Sanni
# 31 Lagos
# 32 10/22/19, 8:39 PM - +234 806 734 7912 joined using this group's invite link
# 33 10/22/19, 8:39 PM - +234 806 734 7912: This message was deleted
# 34 10/22/19, 8:39 PM - +234 818 847 1990 joined using this group's invite link
# 35 10/22/19, 8:39 PM - +234 806 734 7912: We Dey here
# 36 When the python 🐍 class they start
# 37 10/22/19, 8:39 PM - +234 806 734 7912: No time
# 38 10/22/19, 8:41 PM - +234 818 847 1990: Hi Everyone I am Ikechukwu, based in Lagos #AskFeshIntro
# 39 10/22/19, 8:42 PM - +234 818 860 2046 joined using this group's invite link
# 40 10/22/19, 8:42 PM - Adafin: Opeyemi in the building
# 41 10/22/19, 8:43 PM - +234 703 120 1331: Hello All I'm Adedamola I reside in Lagos #AskFeshIntro
# 42 10/22/19, 8:45 PM - +234 803 711 3263 joined using this group's invite link
# 43 10/22/19, 8:49 PM - +234 703 281 5348 joined using this group's invite link
# 44 10/22/19, 8:56 PM - +234 706 130 1525 joined using this group's invite link
# 45 10/22/19, 8:57 PM - +234 812 053 1560 joined using this group's invite link
# 46 10/22/19, 9:01 PM - +234 810 831 6393 joined using this group's invite link
# 47 10/22/19, 9:02 PM - +234 706 277 6106 joined using this group's invite link
# 48 10/22/19, 9:05 PM - +234 818 936 4697 joined using this group's invite link
# 49 10/22/19, 9:06 PM - +234 812 053 1560: print("John Ojo, City: Lagos") #Askfeshintro
# 50 10/22/19, 9:15 PM - +234 903 881 9790 joined using this group's invite link
# 51 10/22/19, 9:26 PM - +234 813 533 2067 joined using this group's invite link
# 52 10/22/19, 9:31 PM - +234 703 553 4253 joined using this group's invite link
# 53 10/22/19, 9:32 PM - +234 813 533 2067: *#Feshintro*
# 54 Name : Agboli Victor
# 55 Location: Kwara state
# 56 10/22/19, 9:35 PM - +234 810 831 6393: #Feshintro
# 57 Name: Muhammad Abiodun Sulaiman
# 58 Location: Lagos State
# 59 10/22/19, 10:08 PM - Francis Obasi D-GASM joined using this group's invite link
# 60 10/22/19, 10:16 PM - +254 717 434244 joined using this group's invite link
# 61 10/22/19, 10:17 PM - Paschal Chukwuemeka Amah: Warm welcome to *#AskPyFesh*! 😁
# 62 Let us please tarry a while (24hrs) to allow folks to join in before we start off. This will give the majority of us the chance to start on the same page.
# 63 Again, warm welcome.
# 64 - _This is Fesh_ 🙇
# 65 #AskFeshIntro
# 66 Location: Lagos.
# 67 10/22/19, 10:18 PM - Paschal Chukwuemeka Amah: PS: Join link will be revoked by then. At least temporarily.
# 68 10/22/19, 10:19 PM - +234 903 915 7667 joined using this group's invite link
# 69 10/22/19, 10:25 PM - +234 806 235 5136 joined using this group's invite link
# 70 10/22/19, 10:29 PM - +234 803 406 5079 joined using this group's invite link
# 71 10/22/19, 11:01 PM - +234 903 895 4127: Hi
# 72 10/22/19, 10:52 PM - +234 805 209 7945 joined using this group's invite link
# 73 10/22/19, 11:01 PM - +234 903 895 4127 joined using this group's invite link
# 74 10/22/19, 11:07 PM - +234 803 509 7061 joined using this group's invite link
# 75 10/22/19, 11:08 PM - +234 803 509 7061: #AskFeshIntro
# 76 Gambo Nurudeen Bello
# 77 From Ilorin
# 78 10/22/19, 11:09 PM - +234 903 895 4127: #AskFeshIntro
# 79 Emeka Boris Ama
# 80 From Port Harcourt
# 81 10/22/19, 11:11 PM - +234 806 235 5136: #AskFeshIntro.   George Peter,  Lagos
# 82 10/22/19, 11:14 PM - +234 706 426 5908 joined using this group's invite link
# 83 10/22/19, 11:23 PM - +234 705 340 6810 joined using this group's invite link
# 84 10/22/19, 11:32 PM - +234 706 214 9878 joined using this group's invite link
# 85 10/22/19, 11:38 PM - +234 706 214 9878: Hi, this is Chukwuma Henry residing in Owerri. #AskFeshIntro
# 86 10/22/19, 11:41 PM - +234 705 340 6810: #AskFeshIntro
# 87 Hi everyone. My name is Ehi and I reside in Port Harcourt.
# 88 10/22/19, 11:51 PM - +234 706 274 2832 joined using this group's invite link
# 89 10/23/19, 12:08 AM - +234 706 753 8706 joined using this group's invite link
# 90 10/23/19, 12:17 AM - +234 708 884 5567 joined using this group's invite link
# 91 10/23/19, 12:31 AM - +234 903 881 9790: #AskFreshIntro
# 92 Oladeji Lawrence
# 93 From Lagos
# 94 10/23/19, 1:02 AM - +234 803 604 4312 joined using this group's invite link
# 95 10/23/19, 1:22 AM - MaduDOMINIC: #AskFeshIntro
# 96 Dominic Madu
# 97 Location: Lagos
# 98 10/23/19, 3:59 AM - +234 701 291 2307 joined using this group's invite link
# 99 10/23/19, 4:20 AM - +234 816 487 0785 joined using this group's invite link
# 100 10/23/19, 5:41 AM - +234 703 059 4261 joined using this group's invite link
# 101 10/23/19, 6:06 AM - +234 903 182 7815 joined using this group's invite link
# 102 10/23/19, 6:30 AM - +34 689 00 06 09 joined using this group's invite link
# 103 10/23/19, 7:16 AM - +234 818 936 4697: #feshintro
# 104 Ayobami-Akanbi Fawaz
# 105 Kwara State.
# 106 10/23/19, 7:18 AM - +234 813 855 8745 joined using this group's invite link
# 107 10/23/19, 7:25 AM - +234 808 230 9647 joined using this group's invite link
# 108 10/23/19, 7:27 AM - +234 813 855 8745: #AskFeshIntro Balogun Oluwabunmi Lagos ...
# 109 10/23/19, 7:32 AM - +234 803 406 5079: #AskFreshIntro
# 110 Jude Ejepu
# 111 Minna, Niger State
# 112 10/23/19, 7:34 AM - +234 906 883 7990: Seghe
# 113 Lagos
# 114 #AskFreshIntro
# 115 10/23/19, 7:50 AM - Paschal Chukwuemeka Amah: _2/3 Repeat message_
# 116 Warm welcome to *#AskPyFesh*! 😁
# 117 Let us please tarry a while (~12hrs) to allow folks to join in before we start off. This will give the majority of us the chance to start on the same page.
# 118 *PS*: Join link will be revoked by then. At least temporarily.
# 119 If you have not, and would want to be enumerated, drop your first message with the tag _*#AskPyFeshIntro*_ with your preferred name and location.
# 120 Again, warm welcome.
# 121 - _This is Fesh_ 🙇
# 122 10/23/19, 7:52 AM - +234 808 230 9647: #AskFreshintro
# 123 Dulo Wegner
# 124 Lagos
# 125 10/23/19, 8:12 AM - +254 717 434244: #AskFreshintro
# 126 Derrick Moses
# 127 Nairobi
# 128 10/23/19, 8:14 AM - +234 701 291 2307: #AskFreshintro
# 129 Joseph Ojo
# 130 Oyo
# 131 10/23/19, 8:15 AM - +234 708 884 5567: #AskFreshintro
# 132 Bamgbose Elizabeth
# 133 Lagos
# 134 10/23/19, 8:20 AM - +263 77 221 3302 joined using this group's invite link
# 135 10/23/19, 8:22 AM - +234 903 182 7815: #AskFreshintro
# 136 Samson Adejoro
# 137 Lagos
# 138 10/23/19, 8:28 AM - +34 689 00 06 09: #AskFreshintro Ade Madrid
# 139 10/23/19, 8:30 AM - +234 706 444 3217: #AskPyFeshIntro
# 140 Chuks
# 141 Lagos
# 142 10/23/19, 8:35 AM - Francis Obasi D-GASM: #AskFreshintro
# 143 Francis Obasi
# 144 Lagos
# 145 10/23/19, 8:35 AM - +234 703 281 5348: #AskFreshIntro
# 146 Adekunle Opeyemi
# 147 Lagos
# 148 10/23/19, 8:41 AM - Adafin: #AskfeshIntro
# 149 Opeyemi Joe
# 150 Lagos
# 151 10/23/19, 8:42 AM - +263 77 221 3302 left
# 152 10/23/19, 8:53 AM - +234 905 488 8162 joined using this group's invite link
# 153 10/23/19, 8:57 AM - +234 706 853 7939 joined using this group's invite link
# 154 10/23/19, 8:57 AM - +234 706 516 7280 joined using this group's invite link
# 155 10/23/19, 9:00 AM - +234 706 853 7939: #AskFeshIntro.
# 156 Name: Tammy
# 157 COR   : Port-Harcourt
# 158 10/23/19, 9:15 AM - +234 905 488 8162: #AskFeshIntro.
# 159 Name: AYOMIDE
# 160 COR   : LAGOS
# 161 10/23/19, 9:24 AM - +234 706 516 7280: #AskFeshIntro.
# 162 Name: JIDE
# 163 COR   : LAGOS
# 164 10/23/19, 9:36 AM - +972 54-226-9638 joined using this group's invite link
# 165 10/23/19, 9:42 AM - +234 812 481 1464 joined using this group's invite link
# 166 10/23/19, 9:47 AM - +234 706 274 2832: #AskFreshintro
# 167 Mayowa
# 168 Lagos
# 169 10/23/19, 10:07 AM - +972 54-226-9638: #Intro
# 170 NL
# 171 Bonn
# 172 10/23/19, 11:04 AM - Charles Echefu #AskPyFesh joined using this group's invite link
# 173 10/23/19, 11:45 AM - +234 805 209 7945: This message was deleted
# 174 10/23/19, 11:45 AM - +234 805 209 7945: *#AskFeshIntro*
# 175 Nkem
# 176 Lagos
# 177 10/23/19, 12:27 PM - Charles Echefu #AskPyFesh: Hello guys am Charles, lagos (Beginners)
# 178 10/23/19, 12:28 PM - +234 706 107 8588 joined using this group's invite link
# 179 10/23/19, 1:02 PM - +234 706 527 3604 joined using this group's invite link
# 180 10/23/19, 1:03 PM - +234 706 527 3604: My name is Tolu Oladipo. I reside in Lagos state #AskFreshIntro
# 181 10/23/19, 1:18 PM - +91 75061 91366 joined using this group's invite link
# 182 10/23/19, 1:30 PM - +234 706 645 5201 joined using this group's invite link
# 183 10/23/19, 2:23 PM - Budo joined using this group's invite link
# 184 10/23/19, 2:39 PM - +91 95986 25625 joined using this group's invite link
# 185 10/23/19, 3:11 PM - +234 706 581 8529 joined using this group's invite link
# 186 10/23/19, 4:00 PM - Ojei Toritsemoshe D-GASM: #AskFeshIntro
# 187 Ojei Tooritse
# 188 Lagos
# 189 10/23/19, 4:21 PM - +91 99231 07798 joined using this group's invite link
# 190 10/23/19, 5:13 PM - +1 (587) 434-5627 joined using this group's invite link
# 191 10/23/19, 5:36 PM - +234 805 177 3961 joined using this group's invite link
# 192 10/23/19, 5:50 PM - +234 818 967 6168 joined using this group's invite link
# 193 10/23/19, 6:08 PM - Obiora Michael D-GASM joined using this group's invite link
# 194 10/23/19, 7:05 PM - Paschal Chukwuemeka Amah: _3/3 Repeat message_
# 195 Warm welcome to *#AskPyFesh*! 😁
# 196 In an hour we shall revoke the join link and open the floor.
# 197 If you have not, and would want to be enumerated, drop your first message with the tag _*#AskPyFeshIntro*_ with your preferred name and location.
# 198 *Upcoming Event*
# 199 _*Time*_: 22:15hrs GMT* (10:15pm Lagos Time)
# 200 _*Agenda*_: Guidance on getting your computer ready to write the language.
# 201 _*Recommended Tools*_: Your laptop or desktop and a working Internet connection.
# 202 Again, warm welcome.
# 203 - == _This is Fesh_ 🙇
# 204 !=_Fresh_ 😀
# 205 10/23/19, 7:07 PM - Obiora Michael D-GASM: Mike, Surulere Lagos #AskPyFeshIntro
# 206 10/23/19, 7:08 PM - +234 805 052 8131: What if my laptop can not connect to WiFi, what do I do?
# 207 10/23/19, 7:08 PM - +91 99231 07798: Sumit, Pune india #AskPyFeshIntro
# 208 10/23/19, 7:13 PM - +234 706 130 1525: #AskFeshIntro
# 209 Mayokun
# 210 Lagos
# 211 10/23/19, 7:13 PM - Paschal Chukwuemeka Amah: Try to find an alternate connection method: via USB, LAN or a modem.
# 212 Some other resources will be suggested when the event starts but all require an internet connection.
# 213 10/23/19, 7:17 PM - +234 805 052 8131: Thanks
# 214 10/23/19, 7:18 PM - +1 (587) 434-5627: #AskFeshIntro
# 215 Thelma
# 216 Calgary
# 217 10/23/19, 7:20 PM - +234 703 059 4261: #AskFeshIntro
# 218 George
# 219 Port Harcourt
# 220 10/23/19, 7:22 PM - Budo: *#AskPyFeshIntro*
# 221 OGB
# 222 Enugu
# 223 10/23/19, 7:25 PM - +234 805 326 3849 joined using this group's invite link
# 224 10/23/19, 7:26 PM - +234 805 326 3849: This message was deleted
# 225 10/23/19, 7:27 PM - +234 812 481 1464: #AskFeshIntro Abimbola Lagos
# 226 10/23/19, 7:38 PM - +234 816 703 4738 joined using this group's invite link
# 227 10/23/19, 7:46 PM - +234 703 553 4253: #AskPyFeshInteo
# 228 Name: Blessing
# 229 Location: Lagos
# 230 10/23/19, 8:00 PM - You revoked this group's invite link
# 231 10/23/19, 8:08 PM - +234 706 853 7939: #AskPyFeshIntro
# 232 Tammy
# 233 Portharcourt
# 234 10/23/19, 8:10 PM - +234 903 182 7815: You can tether tho.
# 235 10/23/19, 8:15 PM - +234 805 326 3849: #AskPyFeshIntro
# 236 Alfred
# 237 Port Harcourt
# 238 10/23/19, 8:54 PM - Paschal Chukwuemeka Amah: To whet our appetite, I will invite us to breeze through this article on LinkedIn. Some of us I'm sure must have seen it. It's a personal account of my _struggle_ to learn the language back in the day.
# 239 It's an assurance to each of us beginning this journey that it is possible to get there:
# 240 (How) I Taught Myself to Code.
# 241 https://www.linkedin.com/pulse/how-i-thought-myself-code-paschal-chukwuemeka-amah
# 242 10/23/19, 8:56 PM - Paschal Chukwuemeka Amah: If you would like to work ahead, follow this step by step guide to install python on your PC:
# 243 Setting Up Python for Data Analysis
# 244 https://www.linkedin.com/pulse/setting-up-python-data-analysis-amah-paschal-chukwuemeka
# 245 10/23/19, 8:57 PM - Charles Echefu #AskPyFesh: #AskPyFeshIntro
# 246 Charles
# 247 Lagos
# 248 10/23/19, 9:00 PM - Paschal Chukwuemeka Amah: *Personal Hacking for the Group*
# 249 Group notifications are notoriously distracting. To mute this group so you get in when you want, tap the three dots at the top right hand corner and hit _mute notifications_.
# 250 To follow links faster on your computer, open whatsapp on your PC by opening web.whatsapp.com in your preferred browser and follow the instructions to connect your account.
# 251 10/23/19, 9:07 PM - +234 706 426 5908: Tunde from Lagos
# 252 10/23/19, 10:16 PM - Paschal Chukwuemeka Amah: It's 10:15pm in Lagos.
# 253 This is Paschal Chukwuemeka Amah.
# 254 I'm excited to welcome you to this WhatsApp group #AskPyFesh!
# 255 Good evening ladies and gentlemen.
# 256 10/23/19, 10:17 PM - +234 706 130 1525: Good evening
# 257 10/23/19, 10:17 PM - Paschal Chukwuemeka Amah: I'm sure we have all gone through the group description and have an idea what this all about.
# 258 I will do quick recap.
# 259 10/23/19, 10:17 PM - Paschal Chukwuemeka Amah: Paschal Chukwuemeka Amah == Fesh.
# 260 So please feel free to use whichever comes faster and more convenient to you.
# 261 10/23/19, 10:18 PM - Paschal Chukwuemeka Amah: This group is geared towards all who are desirous of learning the *python programming language* whatever level they are from beginner to advanced.
# 262 10/23/19, 10:19 PM - Paschal Chukwuemeka Amah: I'm aware we have some fairly proficient developers here and I'm glad we are here together. Your contributions will be most welcome as we go on.
# 263 However, we will start this first event from the *very basics* of learning the language.
# 264 10/23/19, 10:20 PM - Paschal Chukwuemeka Amah: Hopefully you have followed this link and your computer is setup to go. If not, you have it there to use.
# 265 10/23/19, 10:22 PM - Paschal Chukwuemeka Amah: If this is the first programming language you are learning then you are in luck.
# 266 Python is a high level programming language. This means it is closer to human language than machine language. So pretty much every line of python at a closer look, will be readable just like everyday sentences. Well, mostly.
# 267 10/23/19, 10:24 PM - Paschal Chukwuemeka Amah: One of the most puzzling questions for me starting off was: _what can I do with the knowledge of this language_
# 268 If you have not asked yourself this question, I'm not sure what you can take away from this group but just maybe you will get a bit more clarity after this short session.
# 269 10/23/19, 10:25 PM - Paschal Chukwuemeka Amah: Python is a very versatile language and can be used to develop Python can be used to develop different things like web applications, graphic user interface based applications, software development application, scientific and numeric applications, network programming, Games and 3D applications and other business applications.
# 270 10/23/19, 10:26 PM - Paschal Chukwuemeka Amah: Some of the popular services heavily built around python include:
# 271 Google
# 272 YouTube
# 273 Quora
# 274 Dropbox
# 275 Yahoo
# 276 Reddit
# 277 Spotify...
# 278 10/23/19, 10:27 PM - Paschal Chukwuemeka Amah: And... Instagram!
# 279 10/23/19, 10:28 PM - Paschal Chukwuemeka Amah: One of the factors driving the adoption of this language today is its suitability for data and data related operations.
# 280 10/23/19, 10:29 PM - Paschal Chukwuemeka Amah: Of all the various things python can lend itself to, we are mostly going to gravitate towards data analytics and web development. This are arguably two of the most prominent uses of this languages.
# 281 10/23/19, 10:30 PM - Paschal Chukwuemeka Amah: More so, Python is a magnificent scripting language very good at achieving automation of processes.
# 282 10/23/19, 10:31 PM - Paschal Chukwuemeka Amah: To cap up this introduction at the 15minute mark I am going to ask anyone on their computer to pull up the command prompt so we write our very first python program. It consists of a form of ritual in every language: hello world.
# 283 10/23/19, 10:33 PM - Paschal Chukwuemeka Amah: If you followed the setup text and tested it ok as advised, pull up a command prompt and type 'python' then hit the return key.
# 284 You will have the python prompt looking like this
# 285 >>>
# 286 10/23/19, 10:33 PM - Paschal Chukwuemeka Amah: Type in
# 287 _print("Hello World")_
# 288 Hit the return key.
# 289 You just wrote your first script in python.
# 290 10/23/19, 10:37 PM - Paschal Chukwuemeka Amah: I will now outline some resources we can use for learning.
# 291 On a desktop, I will recommend using the *jupyter notebook*
# 292 To get it, download and install Anaconda from this link
# 293 https://www.anaconda.com/distribution/
# 294 At installation, remember to check the box asking to add it to _PATH_ or _environmental variable_
# 295 10/23/19, 10:40 PM - Paschal Chukwuemeka Amah: If you have a low memory PC, don't bother installing Anaconda. It might slow things down for you.
# 296 You can install jupyter notebook and it's dependencies by opening your command prompt and typing
# 297 _pip install jupyter notebook_
# 298 I'm presuming you already have python installed and have an internet connection.
# 299 10/23/19, 10:44 PM - Paschal Chukwuemeka Amah: To launch the notebook, create a new folder somewhere on your desktop, and open it up.
# 300 Hold down the shift key and right click on a blank area (making sure nothing is selected if the folder has any contents), select _open command prompt (or powershell) here_ depending on the version of windows you are using.
# 301 This opens a command prompt in that very directory/folder/location.
# 302 Type:
# 303 _jupyter notebook_
# 304 Hit enter. The notebook fires up and opens on a browser.
# 305 If you are on a Mac or Linux please indicate later if you will need some guidance.
# 306 10/23/19, 10:44 PM - Paschal Chukwuemeka Amah: If you can reach a browser but cannot afford to install packages, the site pythonanywhere.com has resources for you.
# 307 10/23/19, 10:45 PM - Paschal Chukwuemeka Amah: If you are on a mobile, get the app _SoloLearn_.
# 308 The _Code playground_ can be used to write and save code.
# 309 10/23/19, 10:47 PM - Paschal Chukwuemeka Amah: Finally, one of the best _free_ resource I have come across for learning this language is w3schools.com/python
# 310 I will refer to it a lot and will practically follow its outline. Make it your encyclopedia.
# 311 10/23/19, 10:47 PM - Paschal Chukwuemeka Amah: I will stop here for some questions from the house.
# 312 10/23/19, 10:48 PM - Paschal Chukwuemeka Amah: Good evening and welcome once again.
# 313 10/23/19, 10:48 PM - Paschal Chukwuemeka Amah: We'll call it a day at 11:15pm Lagos time.
# 314 10/23/19, 10:51 PM - +234 706 274 2832: Good evening. You said Python is used for web development.
# 315 1. Does it mean that HTML, CSS and JavaScript are outdated?
# 316 2. I'm a newbie in coding and which would you recommend I learn for web development between python and the ones I listed above?
# 317 10/23/19, 10:56 PM - Budo: Python is the way to go
# 318 10/23/19, 10:57 PM - Paschal Chukwuemeka Amah: Web development can be complicated sometimes and many people misunderstand what is required. That said, there are two aspects of web development: the front end and the backend.
# 319 The front end is where the items on _1_ in your list come in. JavaScript has frameworks for the back two. Node.js being the most popular.
# 320 However, the backend is where the logic is the site resides. This is where python frameworks are a great asset. These include Django and Flask amongst others.
# 321 For the web with python, after learning the basics, you will need to zero in on a web framework so you can develop the backend with it. When done, with basic knowledge of HTML and CSS, you get string a front end to it and have a full site from static to full fledged web apps like e-commerce and game sites.
# 322 10/23/19, 10:58 PM - +234 903 182 7815: You can use Python for back end web development. Python web dev frameworks include: Django, Flask and Falcon.
# 323 10/23/19, 10:58 PM - Paschal Chukwuemeka Amah: ✅
# 324 10/23/19, 10:59 PM - +234 903 182 7815: HTML and CSS are not programming languages, they are markup languages.
# 325 10/23/19, 10:59 PM - +234 706 274 2832: Ohh thank you very much 🙂
# 326 10/23/19, 10:59 PM - +234 903 182 7815: HTML and CSS are essential for building a website.
# 327 10/23/19, 11:00 PM - +234 903 182 7815: Python comes in as a replacement to PHP not those ones you mentioned.
# 328 10/23/19, 11:01 PM - Paschal Chukwuemeka Amah: Many thanks Sam. 👍👍
# 329 Let's keep it simple for the beginners and not use too many terms that will confuse them for a take off.
# 330 With time they will get the hang of it.
# 331 10/23/19, 11:02 PM - +234 706 444 3217: so, Python and PHP can't be used together?
# 332 10/23/19, 11:02 PM - +234 903 182 7815: Noted sir.
# 333 Thanks for organizing the platform sir.
# 334 10/23/19, 11:02 PM - Paschal Chukwuemeka Amah: ✌
# 335 10/23/19, 11:02 PM - +234 903 182 7815: No you can't. They both do same thing.
# 336 10/23/19, 11:03 PM - +234 706 444 3217: okay
# 337 10/23/19, 11:03 PM - Charles Echefu #AskPyFesh: Thanks bro
# 338 10/23/19, 11:05 PM - Charles Echefu #AskPyFesh: @Pascal, which one is betterjupyter or anaconda
# 339 10/23/19, 11:06 PM - Charles Echefu #AskPyFesh: Is it advisable to use cmd for coding?
# 340 10/23/19, 11:07 PM - +234 706 214 9878: Thanks Fesh for this wonderful session!
# 341 10/23/19, 11:08 PM - Paschal Chukwuemeka Amah: Jupyter notebook is an environment for writing code. Anaconda is an assemblage of tools and libraries put together for ease of use by developers and one of the many environments in it is the jupyter notebook. Spyder is another environment and it is included in the Anaconda package.
# 342 10/23/19, 11:10 PM - Paschal Chukwuemeka Amah: If you went through the reference text you will see that though you can write code in the command prompt after teaching the python prompt, you have no way of saving it.
# 343 For that it is not advisable to to do as it is mostly a waste of time.
# 344 Use it when you are running your scripts. Something we will get to explain going forward.
# 345 10/23/19, 11:10 PM - Paschal Chukwuemeka Amah: You are welcome Henry. ✌️
# 346 10/23/19, 11:11 PM - Charles Echefu #AskPyFesh: Thanks  Fesh
# 347 10/23/19, 11:12 PM - Charles Echefu #AskPyFesh: I learnt this night
# 348 10/23/19, 11:12 PM - Charles Echefu #AskPyFesh: Any assignment?
# 349 10/23/19, 11:12 PM - Charles Echefu #AskPyFesh: I have that passion
# 350 10/23/19, 11:12 PM - Charles Echefu #AskPyFesh: I want to be like u
# 351 10/23/19, 11:14 PM - Paschal Chukwuemeka Amah: The first for you and for all new people is to get your own computer, install python and get the jupyter notebook.
# 352 This way you will be ready to kick off. Scroll up a bit and find the installation guide.
# 353 Then go ahead to w3schools.com/python and start familiarizing yourself with the basics. Ask questions here when you hit a snag.
# 354 Real take homes will come much later as we progress.
# 355 10/23/19, 11:15 PM - Paschal Chukwuemeka Amah: I'm here to help you get there and far beyond. Just keep moving.
# 356 10/23/19, 11:16 PM - Charles Echefu #AskPyFesh: Thanks Fesh
# 357 10/23/19, 11:16 PM - Charles Echefu #AskPyFesh: When is the meet up ...and the duration.
# 358 10/23/19, 11:17 PM - +234 706 753 8706: Hi @2349081987335. Thank you for this amazing group.
# 359 10/23/19, 11:19 PM - Paschal Chukwuemeka Amah: It's wrap ladies and gentlemen.
# 360 I will answer more questions as they come in on the session we had and generally on beginner stuff. It's important you setup your computer if you want to move along.
# 361 For the rest of us who are not totally new, bear with us as we bring the great new guys up to speed.
# 362 Meanhwile, drop any questions you have on any level of the language and myself and some experienced folk in here will give you a hand.
# 363 Remember _there are several roads to Aba_.
# 364 A single issue can be solved in many ways. The best solution is the one that solves the problem. After that you try the fastest and the least resource sapping.
# 365 Best regards.
# 366 10/23/19, 11:20 PM - Paschal Chukwuemeka Amah: Meets are in the incubator. We will stay here in the virtual world for a while and contemplate meet ups later. They sure are most likely to come.
# 367 10/23/19, 11:21 PM - Charles Echefu #AskPyFesh: I was actually asking for the time for the session
# 368 10/23/19, 11:23 PM - Paschal Chukwuemeka Amah: Oh ok.
# 369 They will be fortnightly if time permits. Either way, they will be announced days ahead.
# 370 Thanks for the clarification. ✌
# 371 10/23/19, 11:23 PM - Charles Echefu #AskPyFesh: Uwc
# 372 10/23/19, 11:25 PM - +234 903 881 9790: Thank you very much @2349081987335 .
# 373 🙌🙌🙌🙌🙌
# 374 10/23/19, 11:26 PM - Paschal Chukwuemeka Amah: In case you are wondering who this guy is, most of all you will need to know are on my LinkedIn profile here:
# 375 https://www.linkedin.com/in/paschal-chukwuemeka-amah-91009369
# 376 From Lagos, do have a good night. And from folks around Africa and the rest of the world here, all the best.
# 377 Let's keep tooling up for the future of work and take our place there.
# 378 10/23/19, 11:27 PM - Paschal Chukwuemeka Amah: You are welcome ✌️
# 379 10/23/19, 11:40 PM - +234 706 527 3604: ...
# 380 10/24/19, 2:10 AM - +234 812 053 1560: Awesome introduction @2349081987335  many thanks for the effort put into this. The contribution too from other experts in the group also help fill in the gaps. Look forward to learning more.
# 381 10/24/19, 7:57 AM - Paschal Chukwuemeka Amah: ✌✌
# 382 10/24/19, 8:18 AM - Paschal Chukwuemeka Amah: *#PythonTip_byFesh*
# 383 Python is object oriented and almost everything in the language is an object. This is a very important aspect that determines a lot of things.
# 384 Every object has its ```properties``` and ```methods``` .
# 385 To work with each, one need know what properties they posses and what ```method``` they respond to.
# 386 To find the type of an object do:
# 387 _type(object)_
# 388 Eg:
# 389 aList = [1, 2, "Fred"]
# 390 aTuple = (1, 2, "Fred")
# 391 aList is a python list and possess the properties as well as responds to the methods of a list.
# 392  ```Properties``` : mutable, iterable.
# 393  ```Methods``` : append(), pop(), index(), sort() etc
# 394 _aTuple_ is a Tuple.
# 395 Essentially a python list but different in that it's ```immutable``` : cannot be changed once created. Responds to two methods _index()_  and _count()_. Being immutable they cannot be sorted, appended to, members popped etc.
# 396 The object type determines what properties it possess and what methods it responds to.
# 397 10/24/19, 8:30 AM - Paschal Chukwuemeka Amah: *Teaser*: Find the basic data types in python, their properties and the methods they respond to.
# 398 Google is your friend.
# 399 Good morning from Lagos. ✌
# 400 _-Fesh-_
# 401 10/24/19, 8:40 AM - +234 812 481 1464: Kudos @2349081987335. Relearning is a very powerful tool in programming. Thank you for the opportunity
# 402 10/24/19, 8:44 AM - Budo: I'm getting confused already ooo
# 403 10/24/19, 8:46 AM - Paschal Chukwuemeka Amah: Don't worry, scrap that part and ask questions if possible for more clarity.
# 404 10/24/19, 9:06 AM - +1 (647) 679-8746 joined using this group's invite link

# %%
len(msgs)
for i, line in enumerate(msgs):
    print(i, line)
# Out:
# 0 10/22/19, 1:26 pm - messages to this group are now secured with end-to-end encryption. tap for more info.
# 1 10/22/19, 1:26 pm - you created group "#askpyfesh "
# 2 10/22/19, 1:28 pm - madudominic: ask python fesh
# 3 10/22/19, 1:28 pm - madudominic: odi ok
# 4 10/22/19, 1:28 pm - madudominic: anyi ebidogo
# 5 10/22/19, 1:30 pm - you changed the group description
# 6 10/22/19, 1:30 PM - Paschal Chukwuemeka Amah: Hehe. na so.
# 7 10/22/19, 1:30 PM - Paschal Chukwuemeka Amah: Trying to find the next big pythonista. so, historically na igwe enter the group first.
# 8 10/22/19, 1:31 pm - paschal chukwuemeka amah: i'll delete all this sha just before i start sharing links and having people join.
# 9 10/22/19, 1:34 pm - you changed this group's icon
# 10 10/22/19, 1:35 pm - you changed this group's icon
# 11 10/22/19, 1:46 pm - you changed the group description
# 12 10/22/19, 8:00 pm - adafin joined using this group's invite link
# 13 10/22/19, 8:00 pm - +234 818 559 0066 joined using this group's invite link
# 14 10/22/19, 8:10 pm - +234 703 120 1331 joined using this group's invite link
# 15 10/22/19, 8:14 pm - +234 906 883 7990 joined using this group's invite link
# 16 10/22/19, 8:17 pm - +234 805 052 8131 joined using this group's invite link
# 17 10/22/19, 8:23 pm - valentine d-gasm joined using this group's invite link
# 18 10/22/19, 8:26 pm - ojei toritsemoshe d-gasm joined using this group's invite link
# 19 10/22/19, 8:32 pm - chigozie njoku d-gasm joined using this group's invite link
# 20 10/22/19, 8:33 PM - Chigozie Njoku D-GASM: #AskFeshIntro Name: Chigozie Njoku city of residence: lagos
# 21 10/22/19, 8:34 pm - +234 706 444 3217 joined using this group's invite link
# 22 10/22/19, 8:34 pm - +234 816 629 7839 joined using this group's invite link
# 23 10/22/19, 8:37 pm - +234 810 004 6353 joined using this group's invite link
# 24 10/22/19, 8:37 pm - +234 810 086 7971 joined using this group's invite link
# 25 10/22/19, 8:39 PM - +234 805 052 8131: #AskFeshIntro Taofik Sanni lagos
# 26 10/22/19, 8:39 pm - +234 806 734 7912 joined using this group's invite link
# 27 10/22/19, 8:39 pm - +234 806 734 7912: this message was deleted
# 28 10/22/19, 8:39 pm - +234 818 847 1990 joined using this group's invite link
# 29 10/22/19, 8:39 PM - +234 806 734 7912: We Dey here  when the python 🐍 class they start
# 30 10/22/19, 8:39 pm - +234 806 734 7912: no time
# 31 10/22/19, 8:41 pm - +234 818 847 1990: hi everyone i am ikechukwu, based in lagos #askfeshintro
# 32 10/22/19, 8:42 pm - +234 818 860 2046 joined using this group's invite link
# 33 10/22/19, 8:42 pm - adafin: opeyemi in the building
# 34 10/22/19, 8:43 pm - +234 703 120 1331: hello all i'm adedamola i reside in lagos #askfeshintro
# 35 10/22/19, 8:45 pm - +234 803 711 3263 joined using this group's invite link
# 36 10/22/19, 8:49 pm - +234 703 281 5348 joined using this group's invite link
# 37 10/22/19, 8:56 pm - +234 706 130 1525 joined using this group's invite link
# 38 10/22/19, 8:57 pm - +234 812 053 1560 joined using this group's invite link
# 39 10/22/19, 9:01 pm - +234 810 831 6393 joined using this group's invite link
# 40 10/22/19, 9:02 pm - +234 706 277 6106 joined using this group's invite link
# 41 10/22/19, 9:05 pm - +234 818 936 4697 joined using this group's invite link
# 42 10/22/19, 9:06 pm - +234 812 053 1560: print("john ojo, city: lagos") #askfeshintro
# 43 10/22/19, 9:15 pm - +234 903 881 9790 joined using this group's invite link
# 44 10/22/19, 9:26 pm - +234 813 533 2067 joined using this group's invite link
# 45 10/22/19, 9:31 pm - +234 703 553 4253 joined using this group's invite link
# 46 10/22/19, 9:32 PM - +234 813 533 2067: *#Feshintro* Name : Agboli Victor location: kwara state
# 47 10/22/19, 9:35 PM - +234 810 831 6393: #Feshintro Name: Muhammad Abiodun Sulaiman location: lagos state
# 48 10/22/19, 10:08 pm - francis obasi d-gasm joined using this group's invite link
# 49 10/22/19, 10:16 pm - +254 717 434244 joined using this group's invite link
# 50 10/22/19, 10:17 PM - Paschal Chukwuemeka Amah: Warm welcome to *#AskPyFesh*! 😁 Let us please tarry a while (24hrs) to allow folks to join in before we start off. This will give the majority of us the chance to start on the same page. Again, warm welcome. - _This is Fesh_ 🙇 #AskFeshIntro location: lagos.
# 51 10/22/19, 10:18 pm - paschal chukwuemeka amah: ps: join link will be revoked by then. at least temporarily.
# 52 10/22/19, 10:19 pm - +234 903 915 7667 joined using this group's invite link
# 53 10/22/19, 10:25 pm - +234 806 235 5136 joined using this group's invite link
# 54 10/22/19, 10:29 pm - +234 803 406 5079 joined using this group's invite link
# 55 10/22/19, 11:01 pm - +234 903 895 4127: hi
# 56 10/22/19, 10:52 pm - +234 805 209 7945 joined using this group's invite link
# 57 10/22/19, 11:01 pm - +234 903 895 4127 joined using this group's invite link
# 58 10/22/19, 11:07 pm - +234 803 509 7061 joined using this group's invite link
# 59 10/22/19, 11:08 PM - +234 803 509 7061: #AskFeshIntro Gambo Nurudeen Bello from ilorin
# 60 10/22/19, 11:09 PM - +234 903 895 4127: #AskFeshIntro  Emeka Boris Ama from port harcourt
# 61 10/22/19, 11:11 pm - +234 806 235 5136: #askfeshintro.   george peter,  lagos
# 62 10/22/19, 11:14 pm - +234 706 426 5908 joined using this group's invite link
# 63 10/22/19, 11:23 pm - +234 705 340 6810 joined using this group's invite link
# 64 10/22/19, 11:32 pm - +234 706 214 9878 joined using this group's invite link
# 65 10/22/19, 11:38 pm - +234 706 214 9878: hi, this is chukwuma henry residing in owerri. #askfeshintro
# 66 10/22/19, 11:41 PM - +234 705 340 6810: #AskFeshIntro  hi everyone. my name is ehi and i reside in port harcourt.
# 67 10/22/19, 11:51 pm - +234 706 274 2832 joined using this group's invite link
# 68 10/23/19, 12:08 am - +234 706 753 8706 joined using this group's invite link
# 69 10/23/19, 12:17 am - +234 708 884 5567 joined using this group's invite link
# 70 10/23/19, 12:31 AM - +234 903 881 9790: #AskFreshIntro Oladeji Lawrence from lagos
# 71 10/23/19, 1:02 am - +234 803 604 4312 joined using this group's invite link
# 72 10/23/19, 1:22 AM - MaduDOMINIC: #AskFeshIntro Dominic Madu location: lagos
# 73 10/23/19, 3:59 am - +234 701 291 2307 joined using this group's invite link
# 74 10/23/19, 4:20 am - +234 816 487 0785 joined using this group's invite link
# 75 10/23/19, 5:41 am - +234 703 059 4261 joined using this group's invite link
# 76 10/23/19, 6:06 am - +234 903 182 7815 joined using this group's invite link
# 77 10/23/19, 6:30 am - +34 689 00 06 09 joined using this group's invite link
# 78 10/23/19, 7:16 AM - +234 818 936 4697: #feshintro Ayobami-Akanbi Fawaz kwara state.
# 79 10/23/19, 7:18 am - +234 813 855 8745 joined using this group's invite link
# 80 10/23/19, 7:25 am - +234 808 230 9647 joined using this group's invite link
# 81 10/23/19, 7:27 am - +234 813 855 8745: #askfeshintro balogun oluwabunmi lagos ...
# 82 10/23/19, 7:32 AM - +234 803 406 5079: #AskFreshIntro Jude Ejepu  minna, niger state
# 83 10/23/19, 7:34 AM - +234 906 883 7990: Seghe Lagos #askfreshintro
# 84 10/23/19, 7:50 AM - Paschal Chukwuemeka Amah: _2/3 Repeat message_ Warm welcome to *#AskPyFesh*! 😁 Let us please tarry a while (~12hrs) to allow folks to join in before we start off. This will give the majority of us the chance to start on the same page. *PS*: Join link will be revoked by then. At least temporarily. If you have not, and would want to be enumerated, drop your first message with the tag _*#AskPyFeshIntro*_ with your preferred name and location. Again, warm welcome. - _this is fesh_ 🙇
# 85 10/23/19, 7:52 AM - +234 808 230 9647: #AskFreshintro Dulo Wegner lagos
# 86 10/23/19, 8:12 AM - +254 717 434244: #AskFreshintro Derrick Moses nairobi
# 87 10/23/19, 8:14 AM - +234 701 291 2307: #AskFreshintro Joseph Ojo oyo
# 88 10/23/19, 8:15 AM - +234 708 884 5567: #AskFreshintro Bamgbose Elizabeth lagos
# 89 10/23/19, 8:20 am - +263 77 221 3302 joined using this group's invite link
# 90 10/23/19, 8:22 AM - +234 903 182 7815: #AskFreshintro Samson Adejoro lagos
# 91 10/23/19, 8:28 am - +34 689 00 06 09: #askfreshintro ade madrid
# 92 10/23/19, 8:30 AM - +234 706 444 3217: #AskPyFeshIntro Chuks lagos
# 93 10/23/19, 8:35 AM - Francis Obasi D-GASM: #AskFreshintro Francis Obasi  lagos
# 94 10/23/19, 8:35 AM - +234 703 281 5348: #AskFreshIntro Adekunle Opeyemi  lagos
# 95 10/23/19, 8:41 AM - Adafin: #AskfeshIntro  Opeyemi Joe  lagos
# 96 10/23/19, 8:42 am - +263 77 221 3302 left
# 97 10/23/19, 8:53 am - +234 905 488 8162 joined using this group's invite link
# 98 10/23/19, 8:57 am - +234 706 853 7939 joined using this group's invite link
# 99 10/23/19, 8:57 am - +234 706 516 7280 joined using this group's invite link
# 100 10/23/19, 9:00 AM - +234 706 853 7939: #AskFeshIntro. Name: Tammy cor   : port-harcourt
# 101 10/23/19, 9:15 AM - +234 905 488 8162: #AskFeshIntro. Name: AYOMIDE cor   : lagos
# 102 10/23/19, 9:24 AM - +234 706 516 7280: #AskFeshIntro. Name: JIDE cor   : lagos
# 103 10/23/19, 9:36 am - +972 54-226-9638 joined using this group's invite link
# 104 10/23/19, 9:42 am - +234 812 481 1464 joined using this group's invite link
# 105 10/23/19, 9:47 AM - +234 706 274 2832: #AskFreshintro Mayowa  lagos
# 106 10/23/19, 10:07 AM - +972 54-226-9638: #Intro NL bonn
# 107 10/23/19, 11:04 am - charles echefu #askpyfesh joined using this group's invite link
# 108 10/23/19, 11:45 am - +234 805 209 7945: this message was deleted
# 109 10/23/19, 11:45 AM - +234 805 209 7945: *#AskFeshIntro* Nkem lagos
# 110 10/23/19, 12:27 pm - charles echefu #askpyfesh: hello guys am charles, lagos (beginners)
# 111 10/23/19, 12:28 pm - +234 706 107 8588 joined using this group's invite link
# 112 10/23/19, 1:02 pm - +234 706 527 3604 joined using this group's invite link
# 113 10/23/19, 1:03 pm - +234 706 527 3604: my name is tolu oladipo. i reside in lagos state #askfreshintro
# 114 10/23/19, 1:18 pm - +91 75061 91366 joined using this group's invite link
# 115 10/23/19, 1:30 pm - +234 706 645 5201 joined using this group's invite link
# 116 10/23/19, 2:23 pm - budo joined using this group's invite link
# 117 10/23/19, 2:39 pm - +91 95986 25625 joined using this group's invite link
# 118 10/23/19, 3:11 pm - +234 706 581 8529 joined using this group's invite link
# 119 10/23/19, 4:00 PM - Ojei Toritsemoshe D-GASM: #AskFeshIntro Ojei Tooritse lagos
# 120 10/23/19, 4:21 pm - +91 99231 07798 joined using this group's invite link
# 121 10/23/19, 5:13 pm - +1 (587) 434-5627 joined using this group's invite link
# 122 10/23/19, 5:36 pm - +234 805 177 3961 joined using this group's invite link
# 123 10/23/19, 5:50 pm - +234 818 967 6168 joined using this group's invite link
# 124 10/23/19, 6:08 pm - obiora michael d-gasm joined using this group's invite link
# 125 10/23/19, 7:05 PM - Paschal Chukwuemeka Amah: _3/3 Repeat message_ Warm welcome to *#AskPyFesh*! 😁 In an hour we shall revoke the join link and open the floor. If you have not, and would want to be enumerated, drop your first message with the tag _*#AskPyFeshIntro*_ with your preferred name and location. *Upcoming Event* _*Time*_: 22:15hrs GMT* (10:15pm Lagos Time) _*Agenda*_: Guidance on getting your computer ready to write the language. _*Recommended Tools*_: Your laptop or desktop and a working Internet connection. Again, warm welcome. - == _This is Fesh_ 🙇 !=_fresh_ 😀
# 126 10/23/19, 7:07 pm - obiora michael d-gasm: mike, surulere lagos #askpyfeshintro
# 127 10/23/19, 7:08 pm - +234 805 052 8131: what if my laptop can not connect to wifi, what do i do?
# 128 10/23/19, 7:08 pm - +91 99231 07798: sumit, pune india #askpyfeshintro
# 129 10/23/19, 7:13 PM - +234 706 130 1525: #AskFeshIntro Mayokun lagos
# 130 10/23/19, 7:13 PM - Paschal Chukwuemeka Amah: Try to find an alternate connection method: via USB, LAN or a modem. some other resources will be suggested when the event starts but all require an internet connection.
# 131 10/23/19, 7:17 pm - +234 805 052 8131: thanks
# 132 10/23/19, 7:18 PM - +1 (587) 434-5627: #AskFeshIntro Thelma calgary
# 133 10/23/19, 7:20 PM - +234 703 059 4261: #AskFeshIntro George  port harcourt
# 134 10/23/19, 7:22 PM - Budo: *#AskPyFeshIntro* OGB enugu
# 135 10/23/19, 7:25 pm - +234 805 326 3849 joined using this group's invite link
# 136 10/23/19, 7:26 pm - +234 805 326 3849: this message was deleted
# 137 10/23/19, 7:27 pm - +234 812 481 1464: #askfeshintro abimbola lagos
# 138 10/23/19, 7:38 pm - +234 816 703 4738 joined using this group's invite link
# 139 10/23/19, 7:46 PM - +234 703 553 4253: #AskPyFeshInteo Name: Blessing location: lagos
# 140 10/23/19, 8:00 pm - you revoked this group's invite link
# 141 10/23/19, 8:08 PM - +234 706 853 7939: #AskPyFeshIntro Tammy portharcourt
# 142 10/23/19, 8:10 pm - +234 903 182 7815: you can tether tho.
# 143 10/23/19, 8:15 PM - +234 805 326 3849: #AskPyFeshIntro Alfred port harcourt
# 144 10/23/19, 8:54 PM - Paschal Chukwuemeka Amah: To whet our appetite, I will invite us to breeze through this article on LinkedIn. Some of us I'm sure must have seen it. It's a personal account of my _struggle_ to learn the language back in the day. It's an assurance to each of us beginning this journey that it is possible to get there: (How) I Taught Myself to Code. https://www.linkedin.com/pulse/how-i-thought-myself-code-paschal-chukwuemeka-amah
# 145 10/23/19, 8:56 PM - Paschal Chukwuemeka Amah: If you would like to work ahead, follow this step by step guide to install python on your PC: Setting Up Python for Data Analysis https://www.linkedin.com/pulse/setting-up-python-data-analysis-amah-paschal-chukwuemeka
# 146 10/23/19, 8:57 PM - Charles Echefu #AskPyFesh: #AskPyFeshIntro Charles  lagos
# 147 10/23/19, 9:00 PM - Paschal Chukwuemeka Amah: *Personal Hacking for the Group* Group notifications are notoriously distracting. To mute this group so you get in when you want, tap the three dots at the top right hand corner and hit _mute notifications_.  to follow links faster on your computer, open whatsapp on your pc by opening web.whatsapp.com in your preferred browser and follow the instructions to connect your account.
# 148 10/23/19, 9:07 pm - +234 706 426 5908: tunde from lagos
# 149 10/23/19, 10:16 PM - Paschal Chukwuemeka Amah: It's 10:15pm in Lagos. This is Paschal Chukwuemeka Amah. I'm excited to welcome you to this WhatsApp group #AskPyFesh! good evening ladies and gentlemen.
# 150 10/23/19, 10:17 pm - +234 706 130 1525: good evening
# 151 10/23/19, 10:17 PM - Paschal Chukwuemeka Amah: I'm sure we have all gone through the group description and have an idea what this all about. i will do quick recap.
# 152 10/23/19, 10:17 PM - Paschal Chukwuemeka Amah: Paschal Chukwuemeka Amah == Fesh. so please feel free to use whichever comes faster and more convenient to you.
# 153 10/23/19, 10:18 pm - paschal chukwuemeka amah: this group is geared towards all who are desirous of learning the *python programming language* whatever level they are from beginner to advanced.
# 154 10/23/19, 10:19 PM - Paschal Chukwuemeka Amah: I'm aware we have some fairly proficient developers here and I'm glad we are here together. Your contributions will be most welcome as we go on. however, we will start this first event from the *very basics* of learning the language.
# 155 10/23/19, 10:20 pm - paschal chukwuemeka amah: hopefully you have followed this link and your computer is setup to go. if not, you have it there to use.
# 156 10/23/19, 10:22 PM - Paschal Chukwuemeka Amah: If this is the first programming language you are learning then you are in luck. python is a high level programming language. this means it is closer to human language than machine language. so pretty much every line of python at a closer look, will be readable just like everyday sentences. well, mostly.
# 157 10/23/19, 10:24 PM - Paschal Chukwuemeka Amah: One of the most puzzling questions for me starting off was: _what can I do with the knowledge of this language_ if you have not asked yourself this question, i'm not sure what you can take away from this group but just maybe you will get a bit more clarity after this short session.
# 158 10/23/19, 10:25 pm - paschal chukwuemeka amah: python is a very versatile language and can be used to develop python can be used to develop different things like web applications, graphic user interface based applications, software development application, scientific and numeric applications, network programming, games and 3d applications and other business applications.
# 159 10/23/19, 10:26 PM - Paschal Chukwuemeka Amah: Some of the popular services heavily built around python include: Google YouTube Quora Dropbox Yahoo Reddit spotify...
# 160 10/23/19, 10:27 pm - paschal chukwuemeka amah: and... instagram!
# 161 10/23/19, 10:28 pm - paschal chukwuemeka amah: one of the factors driving the adoption of this language today is its suitability for data and data related operations.
# 162 10/23/19, 10:29 pm - paschal chukwuemeka amah: of all the various things python can lend itself to, we are mostly going to gravitate towards data analytics and web development. this are arguably two of the most prominent uses of this languages.
# 163 10/23/19, 10:30 pm - paschal chukwuemeka amah: more so, python is a magnificent scripting language very good at achieving automation of processes.
# 164 10/23/19, 10:31 pm - paschal chukwuemeka amah: to cap up this introduction at the 15minute mark i am going to ask anyone on their computer to pull up the command prompt so we write our very first python program. it consists of a form of ritual in every language: hello world.
# 165 10/23/19, 10:33 PM - Paschal Chukwuemeka Amah: If you followed the setup text and tested it ok as advised, pull up a command prompt and type 'python' then hit the return key. You will have the python prompt looking like this >>>
# 166 10/23/19, 10:33 PM - Paschal Chukwuemeka Amah: Type in _print("Hello World")_ Hit the return key. you just wrote your first script in python.
# 167 10/23/19, 10:37 PM - Paschal Chukwuemeka Amah: I will now outline some resources we can use for learning. On a desktop, I will recommend using the *jupyter notebook* To get it, download and install Anaconda from this link https://www.anaconda.com/distribution/ at installation, remember to check the box asking to add it to _path_ or _environmental variable_
# 168 10/23/19, 10:40 PM - Paschal Chukwuemeka Amah: If you have a low memory PC, don't bother installing Anaconda. It might slow things down for you. You can install jupyter notebook and it's dependencies by opening your command prompt and typing _pip install jupyter notebook_ i'm presuming you already have python installed and have an internet connection.
# 169 10/23/19, 10:44 PM - Paschal Chukwuemeka Amah: To launch the notebook, create a new folder somewhere on your desktop, and open it up. Hold down the shift key and right click on a blank area (making sure nothing is selected if the folder has any contents), select _open command prompt (or powershell) here_ depending on the version of windows you are using. This opens a command prompt in that very directory/folder/location. Type: _jupyter notebook_ Hit enter. The notebook fires up and opens on a browser. if you are on a mac or linux please indicate later if you will need some guidance.
# 170 10/23/19, 10:44 pm - paschal chukwuemeka amah: if you can reach a browser but cannot afford to install packages, the site pythonanywhere.com has resources for you.
# 171 10/23/19, 10:45 PM - Paschal Chukwuemeka Amah: If you are on a mobile, get the app _SoloLearn_. the _code playground_ can be used to write and save code.
# 172 10/23/19, 10:47 PM - Paschal Chukwuemeka Amah: Finally, one of the best _free_ resource I have come across for learning this language is w3schools.com/python i will refer to it a lot and will practically follow its outline. make it your encyclopedia.
# 173 10/23/19, 10:47 pm - paschal chukwuemeka amah: i will stop here for some questions from the house.
# 174 10/23/19, 10:48 pm - paschal chukwuemeka amah: good evening and welcome once again.
# 175 10/23/19, 10:48 pm - paschal chukwuemeka amah: we'll call it a day at 11:15pm lagos time.
# 176 10/23/19, 10:51 PM - +234 706 274 2832: Good evening. You said Python is used for web development. 1. Does it mean that HTML, CSS and JavaScript are outdated? 2. i'm a newbie in coding and which would you recommend i learn for web development between python and the ones i listed above?
# 177 10/23/19, 10:56 pm - budo: python is the way to go
# 178 10/23/19, 10:57 PM - Paschal Chukwuemeka Amah: Web development can be complicated sometimes and many people misunderstand what is required. That said, there are two aspects of web development: the front end and the backend. The front end is where the items on _1_ in your list come in. JavaScript has frameworks for the back two. Node.js being the most popular. However, the backend is where the logic is the site resides. This is where python frameworks are a great asset. These include Django and Flask amongst others. for the web with python, after learning the basics, you will need to zero in on a web framework so you can develop the backend with it. when done, with basic knowledge of html and css, you get string a front end to it and have a full site from static to full fledged web apps like e-commerce and game sites.
# 179 10/23/19, 10:58 pm - +234 903 182 7815: you can use python for back end web development. python web dev frameworks include: django, flask and falcon.
# 180 10/23/19, 10:58 pm - paschal chukwuemeka amah: ✅
# 181 10/23/19, 10:59 pm - +234 903 182 7815: html and css are not programming languages, they are markup languages.
# 182 10/23/19, 10:59 pm - +234 706 274 2832: ohh thank you very much 🙂
# 183 10/23/19, 10:59 pm - +234 903 182 7815: html and css are essential for building a website.
# 184 10/23/19, 11:00 pm - +234 903 182 7815: python comes in as a replacement to php not those ones you mentioned.
# 185 10/23/19, 11:01 PM - Paschal Chukwuemeka Amah: Many thanks Sam. 👍👍 Let's keep it simple for the beginners and not use too many terms that will confuse them for a take off. with time they will get the hang of it.
# 186 10/23/19, 11:02 pm - +234 706 444 3217: so, python and php can't be used together?
# 187 10/23/19, 11:02 PM - +234 903 182 7815: Noted sir. thanks for organizing the platform sir.
# 188 10/23/19, 11:02 pm - paschal chukwuemeka amah: ✌
# 189 10/23/19, 11:02 pm - +234 903 182 7815: no you can't. they both do same thing.
# 190 10/23/19, 11:03 pm - +234 706 444 3217: okay
# 191 10/23/19, 11:03 pm - charles echefu #askpyfesh: thanks bro
# 192 10/23/19, 11:05 pm - charles echefu #askpyfesh: @pascal, which one is betterjupyter or anaconda
# 193 10/23/19, 11:06 pm - charles echefu #askpyfesh: is it advisable to use cmd for coding?
# 194 10/23/19, 11:07 pm - +234 706 214 9878: thanks fesh for this wonderful session!
# 195 10/23/19, 11:08 pm - paschal chukwuemeka amah: jupyter notebook is an environment for writing code. anaconda is an assemblage of tools and libraries put together for ease of use by developers and one of the many environments in it is the jupyter notebook. spyder is another environment and it is included in the anaconda package.
# 196 10/23/19, 11:10 PM - Paschal Chukwuemeka Amah: If you went through the reference text you will see that though you can write code in the command prompt after teaching the python prompt, you have no way of saving it. For that it is not advisable to to do as it is mostly a waste of time. use it when you are running your scripts. something we will get to explain going forward.
# 197 10/23/19, 11:10 pm - paschal chukwuemeka amah: you are welcome henry. ✌️
# 198 10/23/19, 11:11 pm - charles echefu #askpyfesh: thanks  fesh
# 199 10/23/19, 11:12 pm - charles echefu #askpyfesh: i learnt this night
# 200 10/23/19, 11:12 pm - charles echefu #askpyfesh: any assignment?
# 201 10/23/19, 11:12 pm - charles echefu #askpyfesh: i have that passion
# 202 10/23/19, 11:12 pm - charles echefu #askpyfesh: i want to be like u
# 203 10/23/19, 11:14 PM - Paschal Chukwuemeka Amah: The first for you and for all new people is to get your own computer, install python and get the jupyter notebook. This way you will be ready to kick off. Scroll up a bit and find the installation guide. Then go ahead to w3schools.com/python and start familiarizing yourself with the basics. Ask questions here when you hit a snag. real take homes will come much later as we progress.
# 204 10/23/19, 11:15 pm - paschal chukwuemeka amah: i'm here to help you get there and far beyond. just keep moving.
# 205 10/23/19, 11:16 pm - charles echefu #askpyfesh: thanks fesh
# 206 10/23/19, 11:16 pm - charles echefu #askpyfesh: when is the meet up ...and the duration.
# 207 10/23/19, 11:17 pm - +234 706 753 8706: hi @2349081987335. thank you for this amazing group.
# 208 10/23/19, 11:19 PM - Paschal Chukwuemeka Amah: It's wrap ladies and gentlemen. I will answer more questions as they come in on the session we had and generally on beginner stuff. It's important you setup your computer if you want to move along. For the rest of us who are not totally new, bear with us as we bring the great new guys up to speed. Meanhwile, drop any questions you have on any level of the language and myself and some experienced folk in here will give you a hand. Remember _there are several roads to Aba_. A single issue can be solved in many ways. The best solution is the one that solves the problem. After that you try the fastest and the least resource sapping. best regards.
# 209 10/23/19, 11:20 pm - paschal chukwuemeka amah: meets are in the incubator. we will stay here in the virtual world for a while and contemplate meet ups later. they sure are most likely to come.
# 210 10/23/19, 11:21 pm - charles echefu #askpyfesh: i was actually asking for the time for the session
# 211 10/23/19, 11:23 PM - Paschal Chukwuemeka Amah: Oh ok. They will be fortnightly if time permits. Either way, they will be announced days ahead. thanks for the clarification. ✌
# 212 10/23/19, 11:23 pm - charles echefu #askpyfesh: uwc
# 213 10/23/19, 11:25 PM - +234 903 881 9790: Thank you very much @2349081987335 . 🙌🙌🙌🙌🙌
# 214 10/23/19, 11:26 PM - Paschal Chukwuemeka Amah: In case you are wondering who this guy is, most of all you will need to know are on my LinkedIn profile here: https://www.linkedin.com/in/paschal-chukwuemeka-amah-91009369 From Lagos, do have a good night. And from folks around Africa and the rest of the world here, all the best. let's keep tooling up for the future of work and take our place there.
# 215 10/23/19, 11:27 pm - paschal chukwuemeka amah: you are welcome ✌️
# 216 10/23/19, 11:40 pm - +234 706 527 3604: ...
# 217 10/24/19, 2:10 am - +234 812 053 1560: awesome introduction @2349081987335  many thanks for the effort put into this. the contribution too from other experts in the group also help fill in the gaps. look forward to learning more.
# 218 10/24/19, 7:57 am - paschal chukwuemeka amah: ✌✌
# 219 10/24/19, 8:18 AM - Paschal Chukwuemeka Amah: *#PythonTip_byFesh* Python is object oriented and almost everything in the language is an object. This is a very important aspect that determines a lot of things. Every object has its ```properties``` and ```methods``` . To work with each, one need know what properties they posses and what ```method``` they respond to. To find the type of an object do: _type(object)_ Eg: aList = [1, 2, "Fred"] aTuple = (1, 2, "Fred")  aList is a python list and possess the properties as well as responds to the methods of a list.  ```Properties``` : mutable, iterable.  ```Methods``` : append(), pop(), index(), sort() etc _aTuple_ is a Tuple. Essentially a python list but different in that it's ```immutable``` : cannot be changed once created. Responds to two methods _index()_  and _count()_. Being immutable they cannot be sorted, appended to, members popped etc. the object type determines what properties it possess and what methods it responds to.
# 220 10/24/19, 8:30 AM - Paschal Chukwuemeka Amah: *Teaser*: Find the basic data types in python, their properties and the methods they respond to. Google is your friend. Good morning from Lagos. ✌ _-fesh-_
# 221 10/24/19, 8:40 am - +234 812 481 1464: kudos @2349081987335. relearning is a very powerful tool in programming. thank you for the opportunity
# 222 10/24/19, 8:44 am - budo: i'm getting confused already ooo
# 223 10/24/19, 8:46 am - paschal chukwuemeka amah: don't worry, scrap that part and ask questions if possible for more clarity.
# 224 10/24/19, 9:06 am - +1 (647) 679-8746 joined using this group's invite link

# %%
intro = [line.lower() for line in msgs if "Intro" in line]

# %%
len(intro)
# Out:
# 27

# %%
intro
# Out:
# ['10/22/19, 8:33 pm - chigozie njoku d-gasm: #askfeshintro name: chigozie njoku city of residence: lagos',
#  '10/22/19, 8:39 pm - +234 805 052 8131: #askfeshintro taofik sanni lagos',
#  '10/22/19, 10:17 pm - paschal chukwuemeka amah: warm welcome to *#askpyfesh*! 😁 let us please tarry a while (24hrs) to allow folks to join in before we start off. this will give the majority of us the chance to start on the same page. again, warm welcome. - _this is fesh_ 🙇 #askfeshintro location: lagos.',
#  '10/22/19, 11:08 pm - +234 803 509 7061: #askfeshintro gambo nurudeen bello from ilorin',
#  '10/22/19, 11:09 pm - +234 903 895 4127: #askfeshintro  emeka boris ama from port harcourt',
#  '10/22/19, 11:41 pm - +234 705 340 6810: #askfeshintro  hi everyone. my name is ehi and i reside in port harcourt.',
#  '10/23/19, 12:31 am - +234 903 881 9790: #askfreshintro oladeji lawrence from lagos',
#  '10/23/19, 1:22 am - madudominic: #askfeshintro dominic madu location: lagos',
#  '10/23/19, 7:32 am - +234 803 406 5079: #askfreshintro jude ejepu  minna, niger state',
#  '10/23/19, 7:50 am - paschal chukwuemeka amah: _2/3 repeat message_ warm welcome to *#askpyfesh*! 😁 let us please tarry a while (~12hrs) to allow folks to join in before we start off. this will give the majority of us the chance to start on the same page. *ps*: join link will be revoked by then. at least temporarily. if you have not, and would want to be enumerated, drop your first message with the tag _*#askpyfeshintro*_ with your preferred name and location. again, warm welcome. - _this is fesh_ 🙇',
#  '10/23/19, 8:30 am - +234 706 444 3217: #askpyfeshintro chuks lagos',
#  '10/23/19, 8:35 am - +234 703 281 5348: #askfreshintro adekunle opeyemi  lagos',
#  '10/23/19, 8:41 am - adafin: #askfeshintro  opeyemi joe  lagos',
#  '10/23/19, 9:00 am - +234 706 853 7939: #askfeshintro. name: tammy cor   : port-harcourt',
#  '10/23/19, 9:15 am - +234 905 488 8162: #askfeshintro. name: ayomide cor   : lagos',
#  '10/23/19, 9:24 am - +234 706 516 7280: #askfeshintro. name: jide cor   : lagos',
#  '10/23/19, 10:07 am - +972 54-226-9638: #intro nl bonn',
#  '10/23/19, 11:45 am - +234 805 209 7945: *#askfeshintro* nkem lagos',
#  '10/23/19, 4:00 pm - ojei toritsemoshe d-gasm: #askfeshintro ojei tooritse lagos',
#  '10/23/19, 7:05 pm - paschal chukwuemeka amah: _3/3 repeat message_ warm welcome to *#askpyfesh*! 😁 in an hour we shall revoke the join link and open the floor. if you have not, and would want to be enumerated, drop your first message with the tag _*#askpyfeshintro*_ with your preferred name and location. *upcoming event* _*time*_: 22:15hrs gmt* (10:15pm lagos time) _*agenda*_: guidance on getting your computer ready to write the language. _*recommended tools*_: your laptop or desktop and a working internet connection. again, warm welcome. - == _this is fesh_ 🙇 !=_fresh_ 😀',
#  '10/23/19, 7:13 pm - +234 706 130 1525: #askfeshintro mayokun lagos',
#  '10/23/19, 7:18 pm - +1 (587) 434-5627: #askfeshintro thelma calgary',
#  '10/23/19, 7:20 pm - +234 703 059 4261: #askfeshintro george  port harcourt',
#  '10/23/19, 7:22 pm - budo: *#askpyfeshintro* ogb enugu',
#  '10/23/19, 8:08 pm - +234 706 853 7939: #askpyfeshintro tammy portharcourt',
#  '10/23/19, 8:15 pm - +234 805 326 3849: #askpyfeshintro alfred port harcourt',
#  '10/23/19, 8:57 pm - charles echefu #askpyfesh: #askpyfeshintro charles  lagos']
